# %%
using Plots
gr()

xs = range(0, 4, length = 5)
y_1 = [2 * xs]
y_2 = [xs / 2 .+ 3 / 2]
plot(xs, [y_1, y_2], title = "Row Picture", linewidth = 5, legend=:topleft)
scatter!((1, 2), annotations = (1.1, 1.8, Plots.text("Solution", :top, :left)), marker = 10, label = false)

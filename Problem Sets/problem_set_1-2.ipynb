# %%
using LinearAlgebra
using Plots
using LaTeXStrings

# %% [markdown]
# ## Problems 1 - 3
#
# The following vectors are utilized for Problems 1 - 3:

# %%
u = [-0.6; 0.8];
v = [4; 3];
w = [1; 2];

# %% [markdown]
# ### Problem 1

# %%
u ⋅ v
# Out:
# 4.440892098500626e-16

# %%
u ⋅ w
# Out:
# 1.0

# %%
u ⋅ (v + w)
# Out:
# 1.0

# %%
w ⋅ v
# Out:
# 10

# %% [markdown]
# ### Problem 2

# %%
length_u = sqrt(u ⋅ u)
# Out:
# 1.0

# %%
length_v = sqrt(v ⋅ v)
# Out:
# 5.0

# %%
length_w = sqrt(w ⋅ w)
# Out:
# 2.23606797749979

# %%
abs(u ⋅ v) <= (length_u * length_v)
# Out:
# true

# %%
abs(v ⋅ w) <= (length_v * length_w)
# Out:
# true

# %% [markdown]
# ### Problem 3

# %%
v⃗ = v / length_v
# Out:
# 2-element Array{Float64,1}:
#  0.8
#  0.6

# %%
w⃗ = w / length_w
# Out:
# 2-element Array{Float64,1}:
#  0.4472135954999579
#  0.8944271909999159

# %%
v⃗ ⋅ w⃗
# Out:
# 0.8944271909999157

# %%
a = w⃗
# Out:
# 2-element Array{Float64,1}:
#  0.4472135954999579
#  0.8944271909999159

# %%
b = [-4; 2]
w⃗ ⋅ (b / sqrt(b ⋅ b))
# Out:
# 0.0

# %%
c = [-1; -2]
w⃗ ⋅ (c / sqrt(c ⋅ c))
# Out:
# -0.9999999999999999

# %%
plot([0, v[1]],
     [0, v[2]],
     label = "v",
     arrow = :head,
     linewidth = 5);
plot!([0, w[1]],
     [0, w[2]],
     framestyle = :zerolines,
     title = "Visualizing Unit Vectors",
     label = "w",
     arrow = :head,
     linewidth = 5,
     legend = :best,
     xlim = (-8, 8),
     ylim = (-5, 5));
plot!([0, v⃗[1]],
     [0, v⃗[2]],
     label = L"$\vec{v}$",
     arrow = :head,
     linewidth = 5);
plot!([0, w⃗[1]],
     [0, w⃗[2]],
     label = L"$\vec{w}$",
     arrow = :head,
     linewidth = 5)

# %%
plot([0, w[1]],
     [0, w[2]],
     framestyle = :zerolines,
     title = "Visualizing Geometry of Vectors",
     label = "w",
     arrow = :head,
     linewidth = 5,
     legend = :best,
     xlim = (-8, 8),
     ylim = (-5, 5));
plot!([0, a[1]],
     [0, a[2]],
     label = L"$a \ (0^{o})$",
     arrow = :head,
     linewidth = 5);
plot!([0, b[1]],
     [0, b[2]],
     label = L"$b \ (90^{o})$",
     arrow = :head,
     linewidth = 5);
plot!([0, c[1]],
     [0, c[2]],
     label = L"$c \ (180^{o})$",
     arrow = :head,
     linewidth = 5)

# %% [markdown]
# ### Problem 19

# %% [markdown]
# ### Three rules for dot products:
#
# 1. $v \cdot w = w \cdot v$
# 2. $u \cdot (v + w) = u \cdot v + u \cdot w$
# 3. $(\alpha v) \cdot w = \alpha(v \cdot w)$

# %% [markdown]
# ### Proof
#
# 1. Substitute into rule 2 the definition of $u = v + w$
#
# > $(v + w) \cdot (v + w) = (v + w) \cdot v + (v + w) \cdot w$
#
# 2. Use rule 1 and rule 3 to simplify
#
# > $(v + w) \cdot (v + w) = v \cdot v + 2(v \cdot w) + w \cdot w$
#
# 3. Use definition of length and dot product to finish proof
#
# > $\| v + w\|^{2} =  v \cdot v + 2(v \cdot w) + w \cdot w$

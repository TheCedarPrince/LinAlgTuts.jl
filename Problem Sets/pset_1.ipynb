# %%
using Plots;
using LinearAlgebra;
using LaTeXStrings;

# %% [markdown]
# # **Section 1.2: Problem 23**
#
# **Problem:** The figure shows that $cos(\alpha) = \frac{v_{1}}{||v||}$ and $sin(\alpha) =
# \frac{v_{2}}{||v||}$. Similarly $cos(\beta)$ is [...] and $sin(\beta)$ is [...]. The angle $\theta$ is $\beta − \alpha$. Substitute into the trigonometry formula $cos(\alpha) cos(\beta) + sin(\beta)sin(\alpha)$ for $cos(\beta −\alpha)$
# to find $cos(\theta) = \frac{v \cdot w}{||v|| \cdot ||w||}$.
#
# ## Solution:
#
# ![Problem 23 image](assets/001-homework-1-2_23.png)
#
# ### Step 1: Find $cos(\beta), \ sin(\beta)$
#
# 1. $cos(\beta) = \frac{w_{1}}{||w||}, \ sin(\beta) = \frac{w_{2}}{||w||}$
#
# ### Step 2: Substitute knowns into $cos(\alpha) cos(\beta) + sin(\beta)sin(\alpha)$
#
# 1. $\frac{v_{1}}{||v||} \frac{w_{1}}{||w||} + \frac{v_{2}}{||v||} \frac{w_{2}}{||w||} = cos(\theta)$
#
# 2. $\frac{v_{1} w_{1} + v_{2} w_{2}}{||v|| \ ||w||} = cos(\theta)$
#
# ### Step 3: Substitute Definition of Dot Product into Step 2
#
# **Definition:** $v \cdot w = v_{1} w_{1} + v_{2} w_{2}$
#
# **Answer:** $\frac{v \cdot w}{||v|| \cdot ||w||} = cos(\theta)$

# %% [markdown]
# # **Section 1.2: Problem 28**
#
# **Problem:** Can three vectors in the $xy$ plane have $u v < 0$ and $v w < 0$ and $u w < 0$?
#
# ## Solution:
#
# **Answer:** Yes, this statement would be valid in this situation. When angle measurements between any of these two vectors are greater than $90^{\circ}$, the dot product between any of these vectors must be negative. An example of a valid solution is as follows:

# %%
u = [1.0, 0];

# %%
v = [-1/2, sqrt(3)/2];

# %%
w = [-1/2, -sqrt(3)/2];

# %%
# The last dot product had to be rounded due to floating point
u ⋅ v == u ⋅ w == round(v ⋅ w, digits = 1)
# Out:
# true

# %% [markdown]
# # **Section 1.3: Problem 4**
#
# Find a combination $x_{1}w_{1} + x_{2}w_{2} + x_{3}w_{3}$ that gives the zero vector:
#
# $ w_{1} = \begin{equation}
# \left[
# \begin{array}{c}
# 1 \\
# 2 \\
# 3 \\
# \end{array}
# \right]
# \end{equation}$
#
# $w_{2} = \begin{equation}
# \left[
# \begin{array}{c}
# 4 \\
# 5 \\
# 6 \\
# \end{array}
# \right]
# \end{equation}
# $
#
# $w_{3} = \begin{equation}
# \left[
# \begin{array}{c}
# 7 \\
# 8 \\
# 9 \\
# \end{array}
# \right]
# \end{equation}$
#
# Those vectors are (independent)/(dependent). The three vectors lie in a [...]. The matrix $W$ with those columns is _not invertible_.

# %% [markdown]
# ## Solution:
#
# $x_{1} = 1$, $x_{2} = -2$, and $x_{3} = 1$. Because these vectors can be summed together to form the zero vector, they are $dependent$ and lie in a $plane$.

# %% [markdown]
# # **Section 1.3: Problem 13**
#
# The very last words say that the $5$ by $5$ centered
# difference matrix is not invertible. Write down the $5$ equations $Cx = b$. Find a
# combination of left sides that gives zero. What combination of $b_{1}$, $b_{2}$, $b_{3}$, $b_{4}$, $b_{5}$ must be zero?

# %% [markdown]
# ## Solution
#
# The equations are given in the following matrix:
#
# $C = \left[
# \begin{array}{ccccc}
# 0 & 1 & 0 & 0 & 0 \\
# -1 & 0 & 1 & 0 & 0 \\
# 0 & -1 & 0 & 1 & 0 \\
# 0 & 0 & -1 & 0 & 1 \\
# 0 & 0 & 0 & -1 & 0 \\
# \end{array}
# \right]$
#
# Summing together $b_{1}$, $b_{3}$, $b_{5}$ yields the zero vector.

# %% [markdown]
# # **Section 2.1: Problem 29**
#
# Start with the vector $u_{0} = (1, 0)$. Multiply again and
# again by the same “Markov matrix” $A = [.8 .3; .2 .7]$. The next three vectors are
# $u_{1}, u_{2}, u_{3}$:
#
# $u_{1}=\left[\begin{array}{ll}.8 & .3 \\ .2 & .7\end{array}\right]\left[\begin{array}{l}1 \\ 0\end{array}\right]=\left[\begin{array}{l}.8 \\ .2\end{array}\right]$
#
# $u_{2} = Au_{1} = [...]$
#
# $u_{3} = Au_{2} = [...]$

# %% [markdown]
# ## Solution
#
# $u_{2} =
# \left[
# \begin{array}{c}
# 0.7 \\
# 0.3 \\
# \end{array}
# \right]$
#
# $u_{3} = \left[
# \begin{array}{c}
# 0.65 \\
# 0.35 \\
# \end{array}
# \right]$
#
# The product of the Markov Matrix times the input vector results in a vector which sums to one.

# %% [markdown]
# # **Section 2.1: Problem 30**

# %% [markdown]
# Continue the previous problem from $u_{0} = (1, 0)$ to $u_{7}$, and also
# from $v_{0} = (0, 1)$ to $v_{7}$. What do you notice about $u_{7}$ and $v_{7}$? Write Julia code to visualize the separate components of the $u$ and $v$ vectors across each step (e.g. something like `plot(component 1 of the first u vector, 1)` and `plot(component 2 of the first u vector, 1)` for each vector generated).
#
# The $u$’s and the $v$’s are approaching a steady state vector $s$. Guess that vector based on the graphs and check that $As = s$. If you start with $s$, then you stay with $s$.

# %% [markdown]
# ## Solution
#
# What follows is an implementation of this visualization in Julia. The first visualization is of the $u$ vectors:

# %%
u = [1; 0];

# %%
v = [0; 1];

# %%
A = [.8 .3; .2 .7];

# %%
u_vecs = [];

# %%
v_vecs = [];

# %%
for i in 1:1:7
    push!(u_vecs, u)
    u = A * u
end

# %%
for i in 1:1:7
    push!(v_vecs, v)
    v = A * v
end

# %%
plot(1:1:7, 
    [nums[1] for nums in u_vecs],
    framestyle=:zerolines,
    label="First Component",
    title="Components of u",
    linewidth = 3);

# %%
plot!(1:1:7,
     [nums[2] for nums in u_vecs],
     label="Second Component",
     linewidth = 3)

# %% [markdown]
# As one can see in this graph, the first and second components of the $u$ vectors appear to be converging to some value. If one were to guess now, the respective values each component would be converging to could be: $\left[
# \begin{array}{c}
# 0.6 \\
# 0.4 \\
# \end{array}
# \right]$
#
# Let's look at the other graph of the $v$ vectors.

# %%
plot(1:1:7, 
    [nums[1] for nums in v_vecs],
    framestyle=:zerolines,
    label="First Component",
    title="Components of v",
    linewidth = 3);

# %%
plot!(1:1:7,
     [nums[2] for nums in v_vecs],
     label="Second Component",
     linewidth = 3)

# %% [markdown]
# Similar to the graph for the $u$ vectors, the first and second components of the $v$ vectors appear to be converging to some value. Taking another guess, the respective values each component would be converging to are: $\left[
# \begin{array}{c}
# 0.6 \\
# 0.4 \\
# \end{array}
# \right]$
#
# To confirm this, multiply the markov matrix with our guess:
#
# $$\left[
# \begin{array}{cc}
# 0.8 & 0.3 \\
# 0.2 & 0.7 \\
# \end{array}
# \right] *
# \left[
# \begin{array}{c}
# 0.6 \\
# 0.4 \\
# \end{array}
# \right] =
# \left[
# \begin{array}{c}
# 0.6 \\
# 0.4 \\
# \end{array}
# \right]$$
#
# This multiplication yields our guess for $s$ and therefore, $s =
# \left[
# \begin{array}{c}
# 0.6 \\
# 0.4 \\
# \end{array}
# \right]$

# %% [markdown]
# # **Section 2.2: Problem 20**
#
#
# ## Solution
#
# The system is singular if row 3 of $A$ is a _linear combination_ of the first two rows. One equation which can't be solved together with the other two equations are $2x + 5y + 4z = 1$.

# %% [markdown]
# # **Section 2.2: Problem 32**
#
# ( a ) Zero
#
# ( b ) Zero
#
# ( c ) Each column of the matrix could be filled with linear multiples of each other row (i.e. column one could be filled with ones, column two filled with twos, ...)
#
# ( d ) The row picture would be a plane in a 100 element space and the column picture would be of 100 vectors all proportional to each other.

# %% [markdown]
# # **Section 2.3: Problem 22**
#
# ( a ) $\sum a_{3j} x_{j}$
#
# ( b ) $a_{21} - a_{11}$
#
# ( c ) $a_{21} - 2a_{11}$
#
# ( d ) $\sum a_{1j}x_{j}$

# %% [markdown]
# # **Section 2.3: Problem 29**
